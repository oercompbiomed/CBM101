# %% [markdown]
# ## Using low dimensional embeddings to discover subtypes of breast cancer
#
# This notebook is largely based on https://towardsdatascience.com/reduce-dimensions-for-single-cell-4224778a2d67 (credit to Nikolay Oskolkov).

# %% [markdown]
# https://www.nature.com/articles/s41467-018-07582-3#data-availability

# %%
import pandas as pd
import numpy as np
import GEOparse
from matplotlib import pyplot as plt

# %%
GEO_ID = "GSE111229" # from the article

# %% [markdown]
# #### Exercise 1. load the dataset into `rna_seq` using GEOparse.

# %%
# %load solutions/ex4_1.py
rna_seq = GEOparse.get_GEO(geo=GEO_ID, destdir="./")
# Out:
# 02-Dec-2020 16:36:10 DEBUG utils - Directory ./ already exists. Skipping.
# 02-Dec-2020 16:36:10 INFO GEOparse - File already exist: using local version.
# 02-Dec-2020 16:36:10 INFO GEOparse - Parsing ./GSE111229_family.soft.gz:
# 02-Dec-2020 16:36:10 DEBUG GEOparse - DATABASE: GeoMiame
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SERIES: GSE111229
# 02-Dec-2020 16:36:10 DEBUG GEOparse - PLATFORM: GPL13112
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025845
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025846
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025847
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025848
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025849
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025850
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025851
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025852
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025853
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025854
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025855
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025856
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025857
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025858
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025859
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025860
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025861
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025862
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025863
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025864
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025865
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025866
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025867
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025868
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025869
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025870
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025871
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025872
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025873
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025874
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025875
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025876
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025877
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025878
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025879
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025880
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025881
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025882
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025883
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025884
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025885
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025886
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025887
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025888
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025889
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025890
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025891
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025892
# 02-Dec-2020 16:36:10 DEBUG GEOparse - SAMPLE: GSM3025893
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025894
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025895
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025896
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025897
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025898
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025899
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025900
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025901
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025902
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025903
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025904
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025905
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025906
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025907
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025908
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025909
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025910
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025911
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025912
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025913
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025914
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025915
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025916
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025917
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025918
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025919
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025920
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025921
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025922
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025923
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025924
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025925
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025926
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025927
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025928
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025929
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025930
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025931
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025932
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025933
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025934
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025935
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025936
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025937
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025938
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025939
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025940
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025941
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025942
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025943
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025944
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025945
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025946
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025947
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025948
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025949
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025950
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025951
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025952
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025953
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025954
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025955
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025956
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025957
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025958
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025959
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025960
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025961
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025962
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025963
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025964
# 02-Dec-2020 16:36:11 DEBUG GEOparse - SAMPLE: GSM3025965
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025966
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025967
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025968
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025969
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025970
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025971
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025972
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025973
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025974
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025975
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025976
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025977
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025978
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025979
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025980
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025981
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025982
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025983
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025984
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025985
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025986
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025987
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025988
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025989
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025990
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025991
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025992
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025993
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025994
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025995
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025996
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025997
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025998
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3025999
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026000
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026001
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026002
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026003
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026004
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026005
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026006
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026007
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026008
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026009
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026010
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026011
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026012
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026013
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026014
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026015
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026016
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026017
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026018
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026019
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026020
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026021
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026022
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026023
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026024
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026025
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026026
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026027
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026028
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026029
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026030
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026031
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026032
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026033
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026034
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026035
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026036
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026037
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026038
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026039
# 02-Dec-2020 16:36:12 DEBUG GEOparse - SAMPLE: GSM3026040
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026041
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026042
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026043
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026044
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026045
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026046
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026047
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026048
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026049
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026050
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026051
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026052
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026053
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026054
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026055
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026056
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026057
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026058
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026059
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026060
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026061
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026062
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026063
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026064
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026065
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026066
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026067
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026068
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026069
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026070
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026071
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026072
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026073
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026074
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026075
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026076
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026077
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026078
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026079
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026080
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026081
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026082
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026083
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026084
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026085
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026086
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026087
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026088
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026089
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026090
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026091
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026092
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026093
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026094
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026095
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026096
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026097
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026098
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026099
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026100
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026101
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026102
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026103
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026104
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026105
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026106
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026107
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026108
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026109
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026110
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026111
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026112
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026113
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026114
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026115
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026116
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026117
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026118
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026119
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026120
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026121
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026122
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026123
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026124
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026125
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026126
# 02-Dec-2020 16:36:13 DEBUG GEOparse - SAMPLE: GSM3026127
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026128
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026129
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026130
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026131
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026132
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026133
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026134
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026135
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026136
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026137
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026138
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026139
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026140
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026141
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026142
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026143
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026144
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026145
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026146
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026147
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026148
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026149
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026150
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026151
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026152
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026153
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026154
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026155
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026156
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026157
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026158
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026159
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026160
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026161
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026162
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026163
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026164
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026165
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026166
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026167
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026168
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026169
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026170
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026171
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026172
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026173
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026174
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026175
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026176
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026177
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026178
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026179
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026180
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026181
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026182
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026183
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026184
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026185
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026186
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026187
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026188
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026189
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026190
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026191
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026192
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026193
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026194
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026195
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026196
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026197
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026198
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026199
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026200
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026201
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026202
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026203
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026204
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026205
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026206
# 02-Dec-2020 16:36:14 DEBUG GEOparse - SAMPLE: GSM3026207
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026208
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026209
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026210
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026211
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026212
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026213
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026214
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026215
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026216
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026217
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026218
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026219
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026220
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026221
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026222
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026223
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026224
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026225
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026226
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026227
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026228
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026229
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026230
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026231
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026232
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026233
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026234
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026235
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026236
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026237
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026238
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026239
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026240
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026241
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026242
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026243
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026244
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026245
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026246
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026247
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026248
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026249
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026250
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026251
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026252
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026253
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026254
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026255
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026256
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026257
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026258
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026259
# 02-Dec-2020 16:36:15 DEBUG GEOparse - SAMPLE: GSM3026260
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026261
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026262
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026263
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026264
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026265
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026266
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026267
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026268
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026269
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026270
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026271
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026272
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026273
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026274
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026275
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026276
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026277
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026278
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026279
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026280
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026281
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026282
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026283
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026284
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026285
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026286
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026287
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026288
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026289
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026290
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026291
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026292
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026293
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026294
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026295
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026296
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026297
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026298
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026299
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026300
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026301
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026302
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026303
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026304
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026305
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026306
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026307
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026308
# 02-Dec-2020 16:36:16 DEBUG GEOparse - SAMPLE: GSM3026309
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026310
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026311
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026312
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026313
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026314
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026315
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026316
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026317
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026318
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026319
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026320
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026321
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026322
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026323
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026324
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026325
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026326
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026327
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026328
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026329
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026330
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026331
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026332
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026333
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026334
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026335
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026336
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026337
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026338
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026339
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026340
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026341
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026342
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026343
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026344
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026345
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026346
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026347
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026348
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026349
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026350
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026351
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026352
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026353
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026354
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026355
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026356
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026357
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026358
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026359
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026360
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026361
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026362
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026363
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026364
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026365
# 02-Dec-2020 16:36:17 DEBUG GEOparse - SAMPLE: GSM3026366
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026367
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026368
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026369
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026370
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026371
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026372
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026373
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026374
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026375
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026376
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026377
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026378
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026379
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026380
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026381
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026382
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026383
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026384
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026385
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026386
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026387
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026388
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026389
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026390
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026391
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026392
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026393
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026394
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026395
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026396
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026397
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026398
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026399
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026400
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026401
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026402
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026403
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026404
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026405
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026406
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026407
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026408
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026409
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026410
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026411
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026412
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026413
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026414
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026415
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026416
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026417
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026418
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026419
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026420
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026421
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026422
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026423
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026424
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026425
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026426
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026427
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026428
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026429
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026430
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026431
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026432
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026433
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026434
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026435
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026436
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026437
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026438
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026439
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026440
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026441
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026442
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026443
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026444
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026445
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026446
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026447
# 02-Dec-2020 16:36:18 DEBUG GEOparse - SAMPLE: GSM3026448
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026449
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026450
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026451
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026452
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026453
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026454
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026455
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026456
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026457
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026458
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026459
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026460
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026461
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026462
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026463
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026464
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026465
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026466
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026467
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026468
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026469
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026470
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026471
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026472
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026473
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026474
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026475
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026476
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026477
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026478
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026479
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026480
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026481
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026482
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026483
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026484
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026485
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026486
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026487
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026488
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026489
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026490
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026491
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026492
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026493
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026494
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026495
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026496
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026497
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026498
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026499
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026500
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026501
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026502
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026503
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026504
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026505
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026506
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026507
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026508
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026509
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026510
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026511
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026512
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026513
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026514
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026515
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026516
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026517
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026518
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026519
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026520
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026521
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026522
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026523
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026524
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026525
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026526
# 02-Dec-2020 16:36:19 DEBUG GEOparse - SAMPLE: GSM3026527
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026528
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026529
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026530
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026531
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026532
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026533
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026534
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026535
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026536
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026537
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026538
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026539
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026540
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026541
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026542
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026543
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026544
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026545
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026546
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026547
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026548
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026549
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026550
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026551
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026552
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026553
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026554
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026555
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026556
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026557
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026558
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026559
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026560
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026561
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026562
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026563
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026564
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026565
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026566
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026567
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026568
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026569
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026570
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026571
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026572
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026573
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026574
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026575
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026576
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026577
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026578
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026579
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026580
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026581
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026582
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026583
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026584
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026585
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026586
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026587
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026588
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026589
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026590
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026591
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026592
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026593
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026594
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026595
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026596
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026597
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026598
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026599
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026600
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026601
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026602
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026603
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026604
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026605
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026606
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026607
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026608
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026609
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026610
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026611
# 02-Dec-2020 16:36:20 DEBUG GEOparse - SAMPLE: GSM3026612

# %%
dir(rna_seq)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_metadata_as_string',
#  '_get_object_as_soft',
#  '_phenotype_data',
#  'database',
#  'download_SRA',
#  'download_supplementary_files',
#  'geotype',
#  'get_accession',
#  'get_metadata_attribute',
#  'get_type',
#  'gpls',
#  'gsms',
#  'merge_and_average',
#  'metadata',
#  'name',
#  'phenotype_data',
#  'pivot_and_annotate',
#  'pivot_samples',
#  'relations',
#  'show_metadata',
#  'to_soft']

# %%
rna_seq.download_SRA??

# %%
rna_seq.geotype
# Out:
# 'SERIES'

# %%
rna_seq.phenotype_data.shape
# Out:
# (768, 37)

# %%
rna_seq.phenotype_data.shape
# Out:
# (768, 37)

# %%
rna_seq.to_soft('test', False)

# %%
cafs = pd.read_csv('data/CAFs.txt', sep='\t')

# %%
sorted(cafs.cluster.unique())
# Out:
# [1, 2, 3, 4]

# %%
expr = cafs

# %% [markdown]
# ### The expression matrix
# 716 cells has been sequenced, and the expression levels has been assessed for 558 genes. Arranging the cells as rows and genes as columns we obtain an *expression matrix*.

# %%
expr.shape
# Out:
# (716, 558)

# %%
expr
# Out:
#                  1110020A21Rik  1110046J04Rik  1190002F15Rik  1500015A07Rik  \
# SS2_15_0048_A3        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A6        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A5        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A4        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A1       43.324338            0.0       0.000000            0.0
# ...                        ...            ...            ...            ...
# SS2_15_0049_P19       0.000000            0.0       0.000000            0.0
# SS2_15_0049_P18      37.696628            0.0       0.000000            0.0
# SS2_15_0049_P21       0.000000            0.0      53.257827            0.0
# SS2_15_0049_P23       0.000000            0.0       0.000000            0.0
# SS2_15_0049_P22       0.000000            0.0       0.000000            0.0
#
#                  1500015O10Rik  1700010K23Rik  1700012D01Rik  1810011H11Rik  \
# SS2_15_0048_A3        0.000000            0.0            0.0       0.000000
# SS2_15_0048_A6        0.000000            0.0            0.0     230.755035
# SS2_15_0048_A5        0.000000            0.0            0.0     375.177236
# SS2_15_0048_A4      891.488043            0.0            0.0       0.000000
# SS2_15_0048_A1        0.000000            0.0            0.0      20.527119
# ...                        ...            ...            ...            ...
# SS2_15_0049_P19    1012.999120            0.0            0.0       0.000000
# SS2_15_0049_P18    1562.238996            0.0            0.0       0.000000
# SS2_15_0049_P21       5.817578            0.0            0.0     112.228306
# SS2_15_0049_P23    2411.205731            0.0            0.0       0.000000
# SS2_15_0049_P22     122.011558            0.0            0.0     593.342291
#
#                  2010204K13Rik  2310057J18Rik  ...  Wif1  Wisp2         Yy2  \
# SS2_15_0048_A3        0.000000       0.000000  ...   0.0    0.0  107.526495
# SS2_15_0048_A6        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A5        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A4        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A1       65.766243       0.000000  ...   0.0    0.0    0.000000
# ...                        ...            ...  ...   ...    ...         ...
# SS2_15_0049_P19      37.231979       0.000000  ...   0.0    0.0   21.453518
# SS2_15_0049_P18       0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0049_P21      62.542484      19.583052  ...   0.0    0.0    0.000000
# SS2_15_0049_P23       0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0049_P22       0.000000       0.000000  ...   0.0    0.0    0.000000
#
#                  Zfp2       Zfp36    Zfp454  Zfp652os  Zfp81     Zfp944  \
# SS2_15_0048_A3    0.0  201.533078  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A6    0.0  175.071938  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A5    0.0  290.743379  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A4    0.0    0.000000  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A1    0.0  768.997431  0.000000       0.0    0.0   2.413509
# ...               ...         ...       ...       ...    ...        ...
# SS2_15_0049_P19   0.0   19.602162  1.869748       0.0    0.0  34.520490
# SS2_15_0049_P18   0.0   41.641731  0.000000       0.0    0.0   0.000000
# SS2_15_0049_P21   0.0   70.246018  0.000000       0.0    0.0   0.000000
# SS2_15_0049_P23   0.0    0.000000  0.000000       0.0    0.0  55.993812
# SS2_15_0049_P22   0.0  390.824106  0.000000       0.0    0.0   0.000000
#
#                  cluster
# SS2_15_0048_A3         1
# SS2_15_0048_A6         1
# SS2_15_0048_A5         1
# SS2_15_0048_A4         2
# SS2_15_0048_A1         1
# ...                  ...
# SS2_15_0049_P19        3
# SS2_15_0049_P18        2
# SS2_15_0049_P21        1
# SS2_15_0049_P23        2
# SS2_15_0049_P22        1
#
# [716 rows x 558 columns]

# %% [markdown]
# Before going further, try to reflect for a moment how you would try to illuminate any pattern in this data, given what you already know.

# %% [markdown]
# #### Plot the expression matrix

# %%
plt.figure(figsize=(8,8))
plt.imshow(expr.values, cmap='Greens', vmax=4000, vmin=0)
plt.title('Expression matrix')
plt.ylabel('Cells')
plt.xlabel('Genes')
plt.colorbar()
plt.show()

# %% [markdown]
# #### Exercise 2. The data is very sparse (most entries are zero), can you quantify how sparse it is? (i.e. how many of the entries are 0)

# %%
# %load solutions/ex4_2.py
np.count_nonzero(expr.values) / np.prod(expr.shape)

# only 20% of the entries are non-zero.
# Out:
# 0.19622154141887427

# %%
print("\n" + "Dimensions of input file: " + str(expr.shape) + "\n")
print("\n" + "Last column corresponds to cluster assignments: " + "\n")
print(expr.iloc[0:4, (expr.shape[1]-4):expr.shape[1]])
X = expr.values[:,0:(expr.shape[1]-1)]
Y = expr.values[:,expr.shape[1]-1] #cluster
X = np.log(X + 1)
# Out:
# Dimensions of input file: (716, 558)
#
#
# Last column corresponds to cluster assignments:
#
#                 Zfp652os  Zfp81  Zfp944  cluster
# SS2_15_0048_A3       0.0    0.0     0.0        1
# SS2_15_0048_A6       0.0    0.0     0.0        1
# SS2_15_0048_A5       0.0    0.0     0.0        1
# SS2_15_0048_A4       0.0    0.0     0.0        2

# %%
cafs.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('int64')], dtype=object)

# %% [markdown]
# ### Decomposing the signals
# Now that we have gained some basic understanding of the data, we see it is fit for machine learning. You have already seen a few techniques to reduce data dimensionality reduction. We start with PCA

# %%
from sklearn.decomposition import PCA

# %%
#from matplotlib import cm
#dir(cm) # available colors

# %% [markdown]
# #### Exercise 3. Perform PCA on the expression data and visualize the results (with colors to represent the ground truth clusters)

# %%
# %load solutions/ex4_3.py
model = PCA()
pca = model.fit_transform(X)
plt.scatter(pca[:, 0], pca[:, 1], c = Y, cmap = 'rainbow', s = 1)
plt.xlabel("PC1", fontsize = 20); plt.ylabel("PC2", fontsize = 20)
# Out:
# Text(0, 0.5, 'PC2')

# %%
plt.plot(model.explained_variance_ratio_[:10])
plt.xticks(range(10));plt.show()

# %% [markdown]
# PCA is completely unsupervised. Linear discriminant analysis (LDA) is often used for the same purpose as PCA (dimensionality reduction), but is strictly speaking not unsupervised.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
model = LinearDiscriminantAnalysis(n_components = 2, priors = None, shrinkage = 'auto', 
                                   solver = 'eigen', store_covariance = False, tol = 0.0001)
lda = model.fit_transform(X, Y)
plt.scatter(lda[:, 0], lda[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.xlabel("LDA1", fontsize = 20); plt.ylabel("LDA2", fontsize = 20)
feature_importances = pd.DataFrame({'Gene':np.array(expr.columns)[:-1], 
                                    'Score':abs(model.coef_[0])})
print(feature_importances.sort_values('Score', ascending = False).head(20))
# Out:
#         Gene      Score
# 422    Rn45s  39.249111
# 64       B2m  12.880958
# 212     Fth1   8.174487
# 287    Lars2   7.385672
# 147     Cst3   6.857356
# 315   Malat1   6.290840
# 420     Rgs5   4.681367
# 524    Timp1   4.486659
# 131   Col3a1   3.229705
# 130   Col1a2   3.062976
# 537  Trmt61b   3.020343
# 145    Crip1   2.991499
# 322      Mgp   2.787057
# 368      Mt1   2.673895
# 400    Postn   2.401428
# 534     Tpm1   2.258763
# 248    Hspa5   2.133318
# 241   Higd1b   2.094767
# 220     Ggt1   2.003810
# 122    Cldn4   1.951643

# %% [markdown]
# The way to interpret the data above: we clearly see the data lay in three clusters, suggesting  we have found 3 different separable expression-signatures. However, we also see one cluster is occupied by 2 clusters (the colors are imposed by the fact that we know the "ground truth", but unsupervised methods are generally used for data exploration in which we do not know of these things.

# %% [markdown]
# # Non-linear methods
#
# # t-SNE
#
# t-SNE is a very popular decomposition technique used in molecular biology, especially for visualization purposes. t-SNE does generally not cope well with high dimensionality, so it is common to first transform the data with PCA and then run this through t-SNE. Here we will do both with and without prereducing the dimensionality.

# %%
from sklearn.manifold import TSNE

# %%
model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
tsne = model.fit_transform(X)

# %%
plt.scatter(tsne[:, 0], tsne[:, 1], c = Y, cmap = 'rainbow', s = 2, marker='x')
plt.title('tSNE', fontsize = 20)
plt.xlabel("tSNE1", fontsize = 20)
plt.ylabel("tSNE2", fontsize = 20)
# Out:
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# #### Exercise 4. Reduce the data first with PCA to 30 principal components, then rerun the tSNE on this transformed data.

# %%
# %load solutions/ex4_4.py
X_reduced = PCA(n_components = 30).fit_transform(X)
model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
tsne = model.fit_transform(X_reduced)

plt.scatter(tsne[:, 0], tsne[:, 1], c = Y, cmap = 'rainbow', s = 2, marker='x')
plt.title('tSNE on PCA', fontsize = 20)
plt.xlabel("tSNE1", fontsize = 20)
plt.ylabel("tSNE2", fontsize = 20)
# Out:
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# While it can be hard to discern the performance boost of prereduction, we can certainly see that t-SNE performs better than a linear method like PCA. However, non-linearity is no guarantee of success itself. For instance Isomap does not do well with this data.

# %%
from sklearn.manifold import Isomap

# %%
model = Isomap()
isomap = model.fit_transform(X)
plt.scatter(isomap[:, 0], isomap[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.title('ISOMAP')
#plt.colorbar()
plt.xlabel("ISO1")
plt.ylabel("ISO2")
# Out:
# Text(0, 0.5, 'ISO2')

# %% [markdown]
# We should not throw Isomap out the window yet, like most algorithm, there is no one-size-fits-all. Isomap is well suited for tasks without clear clusters, but continuous change is present.

# %% [markdown]
# # UMAP
# A more recent alternative to t-SNE is [UMAP](https://arxiv.org/abs/1802.03426), which also produces high quality visualizations with good separation, and scales better than t-sne with large datasets.

# %%
from umap import UMAP

# %%
print("Performing Uniform Manifold Approximation and Projection (UMAP) ...")
#model = UMAP(n_neighbors = 30, min_dist = 0.3, n_components = 2)
model = UMAP()
umap = model.fit_transform(X) # or X_reduced
# Out:
# Performing Uniform Manifold Approximation and Projection (UMAP) ...

# %%
plt.scatter(umap[:, 0], umap[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.title('UMAP')
#plt.colorbar()
plt.xlabel("UMAP1")
plt.ylabel("UMAP2")
# Out:
# Text(0, 0.5, 'UMAP2')

# %% [markdown]
# #### Conclusion
# In summary, when doing data exploration of gene expression (and other biomedical data), non-linear methods are preferred to linear ones.
